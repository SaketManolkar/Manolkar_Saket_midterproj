# %%
from collections import defaultdict
import numpy as np
import pandas as pd
db = pd.read_csv("Nike_dataset.csv",header = None) #THIS FUNCTION IMPORTS THE CSV FILES!!
db.fillna('Zero')
# Out:
#          0               1                2                3   \
# 0    Trans1    Running Shoe            Socks      Sweatshirts
# 1    Trans2    Running Shoe            Socks      Sweatshirts
# 2    Trans3    Running Shoe            Socks      Sweatshirts
# 3    Trans4    Running Shoe      Sweatshirts     Modern Pants
# 4    Trans5    Running Shoe            Socks      Sweatshirts
# 5    Trans6    Running Shoe            Socks      Sweatshirts
# 6    Trans7    Running Shoe            Socks      Sweatshirts
# 7    Trans8  Swimming Shirt            Socks      Sweatshirts
# 8    Trans9  Swimming Shirt       Rash Guard   Dry Fit V-Nick
# 9   Trans10  Swimming Shirt       Rash Guard              Dry
# 10  Trans11  Swimming Shirt       Rash Guard   Dry Fit V-Nick
# 11  Trans12    Running Shoe   Swimming Shirt            Socks
# 12  Trans13    Running Shoe   Swimming Shirt            Socks
# 13  Trans14    Running Shoe   Swimming Shirt       Rash Guard
# 14  Trans15    Running Shoe   Swimming Shirt            Socks
# 15  Trans16  Swimming Shirt      Soccer Shoe          Hoodies
# 16  Trans17    Running Shoe            Socks             Zero
# 17  Trans18           Socks      Sweatshirts     Modern Pants
# 18  Trans19    Running Shoe   Swimming Shirt       Rash Guard
# 19  Trans20    Running Shoe   Swimming Shirt            Socks
#
#                  4              5                6            7   \
# 0      Modern Pants           Zero             Zero         Zero
# 1              Zero           Zero             Zero         Zero
# 2      Modern Pants           Zero             Zero         Zero
# 3              Zero           Zero             Zero         Zero
# 4      Modern Pants    Soccer Shoe             Zero         Zero
# 5              Zero           Zero             Zero         Zero
# 6      Modern Pants     Tech Pants       Rash Guard      Hoodies
# 7              Zero           Zero             Zero         Zero
# 8           Hoodies     Tech Pants             Zero         Zero
# 9              Zero           Zero             Zero         Zero
# 10             Zero           Zero             Zero         Zero
# 11      Sweatshirts   Modern Pants      Soccer Shoe   Rash Guard
# 12      Sweatshirts   Modern Pants      Soccer Shoe   Rash Guard
# 13       Tech Pants        Hoodies   Dry Fit V-Nick         Zero
# 14      Sweatshirts   Modern Pants   Dry Fit V-Nick   Rash Guard
# 15   Dry Fit V-Nick     Tech Pants       Rash Guard         Zero
# 16             Zero           Zero             Zero         Zero
# 17      Soccer Shoe        Hoodies       Rash Guard   Tech Pants
# 18             Zero           Zero             Zero         Zero
# 19      Sweatshirts   Modern Pants      Soccer Shoe      Hoodies
#
#                  8                9                10
# 0              Zero             Zero             Zero
# 1              Zero             Zero             Zero
# 2              Zero             Zero             Zero
# 3              Zero             Zero             Zero
# 4              Zero             Zero             Zero
# 5              Zero             Zero             Zero
# 6              Zero             Zero             Zero
# 7              Zero             Zero             Zero
# 8              Zero             Zero             Zero
# 9              Zero             Zero             Zero
# 10             Zero             Zero             Zero
# 11          Hoodies       Tech Pants   Dry Fit V-Nick
# 12       Tech Pants   Dry Fit V-Nick          Hoodies
# 13             Zero             Zero             Zero
# 14       Tech Pants             Zero             Zero
# 15             Zero             Zero             Zero
# 16             Zero             Zero             Zero
# 17   Dry Fit V-Nick             Zero             Zero
# 18             Zero             Zero             Zero
# 19       Tech Pants       Rash Guard   Dry Fit V-Nick

# %%
db1 = db.values.tolist() #THIS FUCNTIONS CONVERTS CSV FILES INTO LISTS
db1
# Out:
# [['Trans1',
#   'Running Shoe',
#   ' Socks',
#   ' Sweatshirts',
#   ' Modern Pants',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['Trans2',
#   'Running Shoe',
#   ' Socks',
#   ' Sweatshirts',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['Trans3',
#   'Running Shoe',
#   ' Socks',
#   ' Sweatshirts',
#   ' Modern Pants',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['Trans4',
#   'Running Shoe',
#   ' Sweatshirts',
#   ' Modern Pants',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['Trans5',
#   'Running Shoe',
#   ' Socks',
#   ' Sweatshirts',
#   ' Modern Pants',
#   ' Soccer Shoe',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['Trans6',
#   'Running Shoe',
#   ' Socks',
#   ' Sweatshirts',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['Trans7',
#   'Running Shoe',
#   ' Socks',
#   ' Sweatshirts',
#   ' Modern Pants',
#   ' Tech Pants',
#   ' Rash Guard',
#   ' Hoodies',
#   nan,
#   nan,
#   nan],
#  ['Trans8',
#   'Swimming Shirt',
#   ' Socks',
#   ' Sweatshirts',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['Trans9',
#   'Swimming Shirt',
#   ' Rash Guard',
#   ' Dry Fit V-Nick',
#   ' Hoodies',
#   ' Tech Pants',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['Trans10',
#   'Swimming Shirt',
#   ' Rash Guard',
#   ' Dry',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['Trans11',
#   'Swimming Shirt',
#   ' Rash Guard',
#   ' Dry Fit V-Nick',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['Trans12',
#   'Running Shoe',
#   ' Swimming Shirt',
#   ' Socks',
#   ' Sweatshirts',
#   ' Modern Pants',
#   ' Soccer Shoe',
#   ' Rash Guard',
#   ' Hoodies',
#   ' Tech Pants',
#   ' Dry Fit V-Nick'],
#  ['Trans13',
#   'Running Shoe',
#   ' Swimming Shirt',
#   ' Socks',
#   ' Sweatshirts',
#   ' Modern Pants',
#   ' Soccer Shoe',
#   ' Rash Guard',
#   ' Tech Pants',
#   ' Dry Fit V-Nick',
#   ' Hoodies'],
#  ['Trans14',
#   'Running Shoe',
#   ' Swimming Shirt',
#   ' Rash Guard',
#   ' Tech Pants',
#   ' Hoodies',
#   ' Dry Fit V-Nick',
#   nan,
#   nan,
#   nan,
#   nan],
#  ['Trans15',
#   'Running Shoe',
#   ' Swimming Shirt',
#   ' Socks',
#   ' Sweatshirts',
#   ' Modern Pants',
#   ' Dry Fit V-Nick',
#   ' Rash Guard',
#   ' Tech Pants',
#   nan,
#   nan],
#  ['Trans16',
#   'Swimming Shirt',
#   ' Soccer Shoe',
#   ' Hoodies',
#   ' Dry Fit V-Nick',
#   ' Tech Pants',
#   ' Rash Guard',
#   nan,
#   nan,
#   nan,
#   nan],
#  ['Trans17', 'Running Shoe', ' Socks', nan, nan, nan, nan, nan, nan, nan, nan],
#  ['Trans18',
#   'Socks',
#   ' Sweatshirts',
#   ' Modern Pants',
#   ' Soccer Shoe',
#   ' Hoodies',
#   ' Rash Guard',
#   ' Tech Pants',
#   ' Dry Fit V-Nick',
#   nan,
#   nan],
#  ['Trans19',
#   'Running Shoe',
#   ' Swimming Shirt',
#   ' Rash Guard',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['Trans20',
#   'Running Shoe',
#   ' Swimming Shirt',
#   ' Socks',
#   ' Sweatshirts',
#   ' Modern Pants',
#   ' Soccer Shoe',
#   ' Hoodies',
#   ' Tech Pants',
#   ' Rash Guard',
#   ' Dry Fit V-Nick']]

# %%
for i in range(0,len(db1)): #WITH THIS FUNCTION WE CONVERT SIMPLE LISTS INTO NESTED LIST, 
                            #NESTED LISTS ARE EASIER TO PROCESS WITH THIS ALGORITHM 
    new_line=db1[i][0]
    new_line1= db1[i][1:]
    db2=[]
    db2.append(new_line)
    db2.append(new_line1)
    print(db2)
# Out:
# ['Trans1', ['Running Shoe', ' Socks', ' Sweatshirts', ' Modern Pants', nan, nan, nan, nan, nan, nan]]
# ['Trans2', ['Running Shoe', ' Socks', ' Sweatshirts', nan, nan, nan, nan, nan, nan, nan]]
# ['Trans3', ['Running Shoe', ' Socks', ' Sweatshirts', ' Modern Pants', nan, nan, nan, nan, nan, nan]]
# ['Trans4', ['Running Shoe', ' Sweatshirts', ' Modern Pants', nan, nan, nan, nan, nan, nan, nan]]
# ['Trans5', ['Running Shoe', ' Socks', ' Sweatshirts', ' Modern Pants', ' Soccer Shoe', nan, nan, nan, nan, nan]]
# ['Trans6', ['Running Shoe', ' Socks', ' Sweatshirts', nan, nan, nan, nan, nan, nan, nan]]
# ['Trans7', ['Running Shoe', ' Socks', ' Sweatshirts', ' Modern Pants', ' Tech Pants', ' Rash Guard', ' Hoodies', nan, nan, nan]]
# ['Trans8', ['Swimming Shirt', ' Socks', ' Sweatshirts', nan, nan, nan, nan, nan, nan, nan]]
# ['Trans9', ['Swimming Shirt', ' Rash Guard', ' Dry Fit V-Nick', ' Hoodies', ' Tech Pants', nan, nan, nan, nan, nan]]
# ['Trans10', ['Swimming Shirt', ' Rash Guard', ' Dry', nan, nan, nan, nan, nan, nan, nan]]
# ['Trans11', ['Swimming Shirt', ' Rash Guard', ' Dry Fit V-Nick', nan, nan, nan, nan, nan, nan, nan]]
# ['Trans12', ['Running Shoe', ' Swimming Shirt', ' Socks', ' Sweatshirts', ' Modern Pants', ' Soccer Shoe', ' Rash Guard', ' Hoodies', ' Tech Pants', ' Dry Fit V-Nick']]
# ['Trans13', ['Running Shoe', ' Swimming Shirt', ' Socks', ' Sweatshirts', ' Modern Pants', ' Soccer Shoe', ' Rash Guard', ' Tech Pants', ' Dry Fit V-Nick', ' Hoodies']]
# ['Trans14', ['Running Shoe', ' Swimming Shirt', ' Rash Guard', ' Tech Pants', ' Hoodies', ' Dry Fit V-Nick', nan, nan, nan, nan]]
# ['Trans15', ['Running Shoe', ' Swimming Shirt', ' Socks', ' Sweatshirts', ' Modern Pants', ' Dry Fit V-Nick', ' Rash Guard', ' Tech Pants', nan, nan]]
# ['Trans16', ['Swimming Shirt', ' Soccer Shoe', ' Hoodies', ' Dry Fit V-Nick', ' Tech Pants', ' Rash Guard', nan, nan, nan, nan]]
# ['Trans17', ['Running Shoe', ' Socks', nan, nan, nan, nan, nan, nan, nan, nan]]
# ['Trans18', ['Socks', ' Sweatshirts', ' Modern Pants', ' Soccer Shoe', ' Hoodies', ' Rash Guard', ' Tech Pants', ' Dry Fit V-Nick', nan, nan]]
# ['Trans19', ['Running Shoe', ' Swimming Shirt', ' Rash Guard', nan, nan, nan, nan, nan, nan, nan]]
# ['Trans20', ['Running Shoe', ' Swimming Shirt', ' Socks', ' Sweatshirts', ' Modern Pants', ' Soccer Shoe', ' Hoodies', ' Tech Pants', ' Rash Guard', ' Dry Fit V-Nick']]

# %%
db2 = [['Trans1', ['Running Shoe', ' Socks', ' Sweatshirts', ' Modern Pants']]
,['Trans2', ['Running Shoe', ' Socks', ' Sweatshirts']]
,['Trans3', ['Running Shoe', ' Socks', ' Sweatshirts', ' Modern Pants']]
,['Trans4', ['Running Shoe', ' Sweatshirts', ' Modern Pants']]
,['Trans5', ['Running Shoe', ' Socks', ' Sweatshirts', ' Modern Pants', ' Soccer Shoe']]
,['Trans6', ['Running Shoe', ' Socks', ' Sweatshirts']]
,['Trans7', ['Running Shoe', ' Socks', ' Sweatshirts', ' Modern Pants', ' Tech Pants', ' Rash Guard', ' Hoodies']]
,['Trans8', ['Swimming Shirt', ' Socks', ' Sweatshirts']]
,['Trans9', ['Swimming Shirt', ' Rash Guard', ' Dry Fit V-Nick', ' Hoodies', ' Tech Pants']]
,['Trans10', ['Swimming Shirt', ' Rash Guard', ' Dry']]
,['Trans11', ['Swimming Shirt', ' Rash Guard', ' Dry Fit V-Nick']]
,['Trans12', ['Running Shoe', ' Swimming Shirt', ' Socks', ' Sweatshirts', ' Modern Pants', ' Soccer Shoe', ' Rash Guard', ' Hoodies', ' Tech Pants', ' Dry Fit V-Nick']]
,['Trans13', ['Running Shoe', ' Swimming Shirt', ' Socks', ' Sweatshirts', ' Modern Pants', ' Soccer Shoe', ' Rash Guard', ' Tech Pants', ' Dry Fit V-Nick', ' Hoodies']]
,['Trans14', ['Running Shoe', ' Swimming Shirt', ' Rash Guard', ' Tech Pants', ' Hoodies', ' Dry Fit V-Nick']]
,['Trans15', ['Running Shoe', ' Swimming Shirt', ' Socks', ' Sweatshirts', ' Modern Pants', ' Dry Fit V-Nick', ' Rash Guard', ' Tech Pants']]
,['Trans16', ['Swimming Shirt', ' Soccer Shoe', ' Hoodies', ' Dry Fit V-Nick', ' Tech Pants', ' Rash Guard']]
,['Trans17', ['Running Shoe', ' Socks']]
,['Trans18', ['Socks', ' Sweatshirts', ' Modern Pants', ' Soccer Shoe', ' Hoodies', ' Rash Guard', ' Tech Pants', ' Dry Fit V-Nick']]
,['Trans19', ['Running Shoe', ' Swimming Shirt', ' Rash Guard']]
,['Trans20', ['Running Shoe', ' Swimming Shirt', ' Socks', ' Sweatshirts', ' Modern Pants', ' Soccer Shoe', ' Hoodies', ' Tech Pants', ' Rash Guard', ' Dry Fit V-Nick']]]

# %%
init = []      # THIS FUNCTION SPECIFIES ALL THE INDIVISUAL ITEMSETS IN THE TRANSACTIONS
for i in db2:
    for q in i[1]:
        if(q not in init):
            init.append(q)

print(init)
# Out:
# ['Running Shoe', ' Socks', ' Sweatshirts', ' Modern Pants', ' Soccer Shoe', ' Tech Pants', ' Rash Guard', ' Hoodies', 'Swimming Shirt', ' Dry Fit V-Nick', ' Dry', ' Swimming Shirt', 'Socks']

# %%
support = 0.70
s = int(support*len(init))

# %%
from collections import Counter #THIS FUCNTION CALCULATES C1 AND L1 WITH RESPECT TO MINIMUM SUPPORT
c = Counter()
for i in init:
    for d in db2:
        if(i in d[1]):
            c[i]+=1
print("C1:")
for i in c:
    print(str([i])+": "+str(c[i]))
print()
l = Counter()
for i in c:
    if(c[i] >= s):
        l[frozenset([i])]+=c[i]
print("L1:")
for i in l:
    print(str(list(i))+": "+str(l[i]))
print()
# Out:
# C1:
# ['Running Shoe']: 14
# [' Socks']: 12
# [' Sweatshirts']: 13
# [' Modern Pants']: 10
# [' Soccer Shoe']: 6
# [' Tech Pants']: 9
# [' Rash Guard']: 12
# [' Hoodies']: 8
# ['Swimming Shirt']: 5
# [' Dry Fit V-Nick']: 9
# [' Dry']: 1
# [' Swimming Shirt']: 6
# ['Socks']: 1
#
# L1:
# ['Running Shoe']: 14
# [' Socks']: 12
# [' Sweatshirts']: 13
# [' Modern Pants']: 10
# [' Tech Pants']: 9
# [' Rash Guard']: 12
# [' Dry Fit V-Nick']: 9

# %%
pl = l  #THIS FUCNTION IS FILLED WITH FOR LOOPS TO CONTINUOUS CALCULATE Cs AND Ls beyond C1 AND L1 UNTIL THERE IS ONLY ONE COMBINATION LEFT
pos = 1
for count in range (2,1000):
    nc = set()
    temp = list(l)
    for i in range(0,len(temp)):
        for j in range(i+1,len(temp)):
            t = temp[i].union(temp[j])
            if(len(t) == count):
                nc.add(temp[i].union(temp[j]))
    nc = list(nc)
    c = Counter()
    for i in nc:
        c[i] = 0
        for q in db2:
            temp = set(q[1])
            if(i.issubset(temp)):
                c[i]+=1
    print("C"+str(count)+":")
    for i in c:
        print(str(list(i))+": "+str(c[i]))
    print()
    l = Counter()
    for i in c:
        if(c[i] >= s):
            l[i]+=c[i]
    print("L"+str(count)+":")
    for i in l:
        print(str(list(i))+": "+str(l[i]))
    print()
    if(len(l) == 0):
        break
    pl = l
    pos = count
print("Result: ")
print("L"+str(pos)+":")
for i in pl:
    print(str(list(i))+": "+str(pl[i]))
print()
from itertools import combinations
for l in pl:
    c = [frozenset(q) for q in combinations(l,len(l)-1)]
    mmax = 0
    for a in c:
        b = l-a
        ab = l
        sab = 0
        sa = 0
        sb = 0
        for q in db2:
            temp = set(q[1])
            if(a.issubset(temp)):
                sa+=1
            if(b.issubset(temp)):
                sb+=1
            if(ab.issubset(temp)):
                sab+=1
        temp = sab/sa*100
        if(temp > mmax):
            mmax = temp
        temp = sab/sb*100
        if(temp > mmax):
            mmax = temp
        print(str(list(a))+" -> "+str(list(b))+" = "+str(sab/sa*100)+"%")
        print(str(list(b))+" -> "+str(list(a))+" = "+str(sab/sb*100)+"%")
    curr = 1
    print("choosing:", end=' ')
    for a in c:
        b = l-a
        ab = l
        sab = 0
        sa = 0
        sb = 0
        for q in db2:
            temp = set(q[1])
            if(a.issubset(temp)):
                sa+=1
            if(b.issubset(temp)):
                sb+=1
            if(ab.issubset(temp)):
                sab+=1
        temp = sab/sa*100
        if(temp == mmax):
            print(curr, end = ' ')
        curr += 1
        temp = sab/sb*100
        if(temp == mmax):
            print(curr, end = ' ')
        curr += 1
    print()
    print()
# Out:
# C2:
# [' Modern Pants', ' Rash Guard']: 6
# [' Tech Pants', 'Running Shoe']: 6
# [' Modern Pants', 'Running Shoe']: 9
# [' Rash Guard', ' Dry Fit V-Nick']: 9
# [' Rash Guard', ' Socks']: 5
# [' Sweatshirts', ' Dry Fit V-Nick']: 5
# [' Modern Pants', ' Socks']: 8
# [' Sweatshirts', ' Socks']: 11
# [' Sweatshirts', ' Tech Pants']: 6
# [' Rash Guard', ' Tech Pants']: 9
# [' Dry Fit V-Nick', ' Socks']: 4
# [' Tech Pants', ' Dry Fit V-Nick']: 8
# [' Modern Pants', ' Dry Fit V-Nick']: 5
# [' Modern Pants', ' Sweatshirts']: 10
# [' Sweatshirts', 'Running Shoe']: 11
# [' Tech Pants', ' Socks']: 5
# [' Socks', 'Running Shoe']: 11
# [' Dry Fit V-Nick', 'Running Shoe']: 5
# [' Modern Pants', ' Tech Pants']: 6
# [' Rash Guard', 'Running Shoe']: 7
# [' Rash Guard', ' Sweatshirts']: 6
#
# L2:
# [' Modern Pants', 'Running Shoe']: 9
# [' Rash Guard', ' Dry Fit V-Nick']: 9
# [' Sweatshirts', ' Socks']: 11
# [' Rash Guard', ' Tech Pants']: 9
# [' Modern Pants', ' Sweatshirts']: 10
# [' Sweatshirts', 'Running Shoe']: 11
# [' Socks', 'Running Shoe']: 11
#
# C3:
# [' Sweatshirts', ' Socks', 'Running Shoe']: 10
# [' Modern Pants', ' Sweatshirts', 'Running Shoe']: 9
# [' Rash Guard', ' Tech Pants', ' Dry Fit V-Nick']: 8
# [' Modern Pants', ' Socks', 'Running Shoe']: 8
# [' Modern Pants', ' Sweatshirts', ' Socks']: 8
#
# L3:
# [' Sweatshirts', ' Socks', 'Running Shoe']: 10
# [' Modern Pants', ' Sweatshirts', 'Running Shoe']: 9
#
# C4:
# [' Modern Pants', ' Sweatshirts', 'Running Shoe', ' Socks']: 8
#
# L4:
#
# Result:
# L3:
# [' Sweatshirts', ' Socks', 'Running Shoe']: 10
# [' Modern Pants', ' Sweatshirts', 'Running Shoe']: 9
#
# [' Sweatshirts', ' Socks'] -> ['Running Shoe'] = 90.9090909090909%
# ['Running Shoe'] -> [' Sweatshirts', ' Socks'] = 71.42857142857143%
# [' Sweatshirts', 'Running Shoe'] -> [' Socks'] = 90.9090909090909%
# [' Socks'] -> [' Sweatshirts', 'Running Shoe'] = 83.33333333333334%
# [' Socks', 'Running Shoe'] -> [' Sweatshirts'] = 90.9090909090909%
# [' Sweatshirts'] -> [' Socks', 'Running Shoe'] = 76.92307692307693%
# choosing: 1 3 5
#
# [' Modern Pants', ' Sweatshirts'] -> ['Running Shoe'] = 90.0%
# ['Running Shoe'] -> [' Modern Pants', ' Sweatshirts'] = 64.28571428571429%
# [' Modern Pants', 'Running Shoe'] -> [' Sweatshirts'] = 100.0%
# [' Sweatshirts'] -> [' Modern Pants', 'Running Shoe'] = 69.23076923076923%
# [' Sweatshirts', 'Running Shoe'] -> [' Modern Pants'] = 81.81818181818183%
# [' Modern Pants'] -> [' Sweatshirts', 'Running Shoe'] = 90.0%
# choosing: 3

# %%
from itertools import combinations
for l in pl:
    c = [frozenset(q) for q in combinations(l,len(l)-1)]
    mmax = 0
    for a in c:
        b = l-a
        ab = l
        sab = 0
        
        sa = 0
        sb = 0
        for q in db2:
            temp = set(q[1])
            if(a.issubset(temp)):
                sa+=1
            if(b.issubset(temp)):
                sb+=1
            if(ab.issubset(temp)):
                sab+=1
        temp = sab/sa*100
        if(temp > mmax):
            mmax = temp
        temp = sab/sb*100
        if(temp > mmax):
            mmax = temp
        print(str(list(a))+" -> "+str(list(b))+" = "+str(sab/sa*100)+"%")
        print(str(list(b))+" -> "+str(list(a))+" = "+str(sab/sb*100)+"%")
    curr = 1
    print("choosing:", end=' ')
    for a in c:
        b = l-a
        ab = l
        sab = 0
        sa = 0
        sb = 0
        for q in db2:
            temp = set(q[1])
            if(a.issubset(temp)):
                sa+=1
            if(b.issubset(temp)):
                sb+=1
            if(ab.issubset(temp)):
                sab+=1
        temp = sab/sa*100
        if(temp == mmax):
            print(curr, end = ' ')
        curr += 1
        temp = sab/sb*100
        if(temp == mmax):
            print(curr, end = ' ')
        curr += 1
    print()
    print()
# Out:
# [' Sweatshirts', ' Socks'] -> ['Running Shoe'] = 90.9090909090909%
# ['Running Shoe'] -> [' Sweatshirts', ' Socks'] = 71.42857142857143%
# [' Sweatshirts', 'Running Shoe'] -> [' Socks'] = 90.9090909090909%
# [' Socks'] -> [' Sweatshirts', 'Running Shoe'] = 83.33333333333334%
# [' Socks', 'Running Shoe'] -> [' Sweatshirts'] = 90.9090909090909%
# [' Sweatshirts'] -> [' Socks', 'Running Shoe'] = 76.92307692307693%
# choosing: 1 3 5
#
# [' Modern Pants', ' Sweatshirts'] -> ['Running Shoe'] = 90.0%
# ['Running Shoe'] -> [' Modern Pants', ' Sweatshirts'] = 64.28571428571429%
# [' Modern Pants', 'Running Shoe'] -> [' Sweatshirts'] = 100.0%
# [' Sweatshirts'] -> [' Modern Pants', 'Running Shoe'] = 69.23076923076923%
# [' Sweatshirts', 'Running Shoe'] -> [' Modern Pants'] = 81.81818181818183%
# [' Modern Pants'] -> [' Sweatshirts', 'Running Shoe'] = 90.0%
# choosing: 3
