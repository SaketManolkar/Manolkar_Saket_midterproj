# %%
from collections import defaultdict
import numpy as np
import pandas as pd
db = pd.read_csv("Kmart_dataset.csv",header = None) #THIS FUNCTION IMPORTS THE CSV FILES!!
db.fillna('Zero')
# Out:
#           0                      1                       2  \
# 0    Trans1     Decorative Pillows                  Quilts
# 1    Trans2  Embroidered Bedspread                   Shams
# 2    Trans3     Decorative Pillows                  Quilts
# 3    Trans4           Kids Bedding     Bedding Collections
# 4    Trans5     Decorative Pillows            Kids Bedding
# 5    Trans6    Bedding Collections              Bedspreads
# 6    Trans7     Decorative Pillows                  Quilts
# 7    Trans8     Decorative Pillows                  Quilts
# 8    Trans9             Bedspreads              Bed Skirts
# 9   Trans10                 Quilts   Embroidered Bedspread
# 10  Trans11    Bedding Collections              Bedspreads
# 11  Trans12     Decorative Pillows                  Quilts
# 12  Trans13  Embroidered Bedspread                   Shams
# 13  Trans14                 Sheets                   Shams
# 14  Trans15     Decorative Pillows                  Quilts
# 15  Trans16     Decorative Pillows            Kids Bedding
# 16  Trans17     Decorative Pillows                   Shams
# 17  Trans18                 Quilts                  Sheets
# 18  Trans19                  Shams              Bed Skirts
# 19  Trans20     Decorative Pillows              Bedspreads
#
#                          3                     4              5  \
# 0    Embroidered Bedspread                  Zero           Zero
# 1             Kids Bedding   Bedding Collections     Bed Skirts
# 2    Embroidered Bedspread                 Shams   Kids Bedding
# 3                   Sheets            Bedspreads     Bed Skirts
# 4      Bedding Collections                Sheets     Bed Skirts
# 5               Bed Skirts                Sheets          Shams
# 6    Embroidered Bedspread                  Zero           Zero
# 7                     Zero                  Zero           Zero
# 8                    Shams          Kids Bedding         Sheets
# 9      Bedding Collections                  Zero           Zero
# 10              Bed Skirts          Kids Bedding          Shams
# 11                    Zero                  Zero           Zero
# 12                    Zero                  Zero           Zero
# 13              Bed Skirts          Kids Bedding           Zero
# 14                    Zero                  Zero           Zero
# 15              Bed Skirts                 Shams           Zero
# 16              Bed Skirts                  Zero           Zero
# 17            Kids Bedding                  Zero           Zero
# 18            Kids Bedding                Sheets           Zero
# 19                   Shams                Sheets     Bed Skirts
#
#                        6        7
# 0                   Zero     Zero
# 1             Bedspreads   Sheets
# 2    Bedding Collections     Zero
# 3                   Zero     Zero
# 4             Bedspreads     Zero
# 5           Kids Bedding     Zero
# 6                   Zero     Zero
# 7                   Zero     Zero
# 8                   Zero     Zero
# 9                   Zero     Zero
# 10                Sheets     Zero
# 11                  Zero     Zero
# 12                  Zero     Zero
# 13                  Zero     Zero
# 14                  Zero     Zero
# 15                  Zero     Zero
# 16                  Zero     Zero
# 17                  Zero     Zero
# 18                  Zero     Zero
# 19          Kids Bedding     Zero

# %%
db1 = db.values.tolist() #THIS FUCNTIONS CONVERTS CSV FILES INTO LISTS
db1
# Out:
# [['Trans1',
#   'Decorative Pillows',
#   ' Quilts',
#   ' Embroidered Bedspread',
#   nan,
#   nan,
#   nan,
#   nan],
#  ['Trans2',
#   'Embroidered Bedspread',
#   ' Shams',
#   ' Kids Bedding',
#   ' Bedding Collections',
#   ' Bed Skirts',
#   ' Bedspreads',
#   ' Sheets'],
#  ['Trans3',
#   'Decorative Pillows',
#   ' Quilts',
#   ' Embroidered Bedspread',
#   ' Shams',
#   ' Kids Bedding',
#   ' Bedding Collections',
#   nan],
#  ['Trans4',
#   'Kids Bedding',
#   ' Bedding Collections',
#   ' Sheets',
#   ' Bedspreads',
#   ' Bed Skirts',
#   nan,
#   nan],
#  ['Trans5',
#   'Decorative Pillows',
#   ' Kids Bedding',
#   ' Bedding Collections',
#   ' Sheets',
#   ' Bed Skirts',
#   ' Bedspreads',
#   nan],
#  ['Trans6',
#   'Bedding Collections',
#   ' Bedspreads',
#   ' Bed Skirts',
#   ' Sheets',
#   ' Shams',
#   ' Kids Bedding',
#   nan],
#  ['Trans7',
#   'Decorative Pillows',
#   ' Quilts',
#   ' Embroidered Bedspread',
#   nan,
#   nan,
#   nan,
#   nan],
#  ['Trans8', 'Decorative Pillows', ' Quilts', nan, nan, nan, nan, nan],
#  ['Trans9',
#   'Bedspreads',
#   ' Bed Skirts',
#   ' Shams',
#   ' Kids Bedding',
#   ' Sheets',
#   nan,
#   nan],
#  ['Trans10',
#   'Quilts',
#   ' Embroidered Bedspread',
#   ' Bedding Collections',
#   nan,
#   nan,
#   nan,
#   nan],
#  ['Trans11',
#   'Bedding Collections',
#   ' Bedspreads',
#   ' Bed Skirts',
#   ' Kids Bedding',
#   ' Shams',
#   ' Sheets',
#   nan],
#  ['Trans12', 'Decorative Pillows', ' Quilts', nan, nan, nan, nan, nan],
#  ['Trans13', 'Embroidered Bedspread', ' Shams', nan, nan, nan, nan, nan],
#  ['Trans14',
#   'Sheets',
#   ' Shams',
#   ' Bed Skirts',
#   ' Kids Bedding',
#   nan,
#   nan,
#   nan],
#  ['Trans15', 'Decorative Pillows', ' Quilts', nan, nan, nan, nan, nan],
#  ['Trans16',
#   'Decorative Pillows',
#   ' Kids Bedding',
#   ' Bed Skirts',
#   ' Shams',
#   nan,
#   nan,
#   nan],
#  ['Trans17',
#   'Decorative Pillows',
#   ' Shams',
#   ' Bed Skirts',
#   nan,
#   nan,
#   nan,
#   nan],
#  ['Trans18', 'Quilts', ' Sheets', ' Kids Bedding', nan, nan, nan, nan],
#  ['Trans19',
#   'Shams',
#   ' Bed Skirts',
#   ' Kids Bedding',
#   ' Sheets',
#   nan,
#   nan,
#   nan],
#  ['Trans20',
#   'Decorative Pillows',
#   ' Bedspreads',
#   ' Shams',
#   ' Sheets',
#   ' Bed Skirts',
#   ' Kids Bedding',
#   nan]]

# %%
for i in range(0,len(db1)): #WITH THIS FUNCTION WE CONVERT SIMPLE LISTS INTO NESTED LIST, 
                            #NESTED LISTS ARE EASIER TO PROCESS WITH THIS ALGORITHM 
# %%
init = []      # THIS FUNCTION SPECIFIES ALL THE INDIVISUAL ITEMSETS IN THE TRANSACTIONS
for i in db2:
    for q in i[1]:
        if(q not in init):
            init.append(q)

print(init)
# Out:
# ['Decorative Pillows', ' Quilts', ' Embroidered Bedspread', 'Embroidered Bedspread', ' Shams', ' Kids Bedding', ' Bedding Collections', ' Bed Skirts', ' Bedspreads', ' Sheets', 'Kids Bedding', 'Bedding Collections', 'Bedspreads', 'Quilts', 'Sheets', 'Shams']

# %%
support = 0.70
s = int(support*len(init))

# %%
from collections import Counter #THIS FUCNTION CALCULATES C1 AND L1 WITH RESPECT TO MINIMUM SUPPORT
c = Counter()
for i in init:
    for d in db2:
        if(i in d[1]):
            c[i]+=1
print("C1:")
for i in c:
    print(str([i])+": "+str(c[i]))
print()
l = Counter()
for i in c:
    if(c[i] >= s):
        l[frozenset([i])]+=c[i]
print("L1:")
for i in l:
    print(str(list(i))+": "+str(l[i]))
print()
# Out:
# C1:
# ['Decorative Pillows']: 10
# [' Quilts']: 6
# [' Embroidered Bedspread']: 4
# ['Embroidered Bedspread']: 2
# [' Shams']: 10
# [' Kids Bedding']: 11
# [' Bedding Collections']: 5
# [' Bed Skirts']: 11
# [' Bedspreads']: 6
# [' Sheets']: 9
# ['Kids Bedding']: 1
# ['Bedding Collections']: 2
# ['Bedspreads']: 1
# ['Quilts']: 2
# ['Sheets']: 1
# ['Shams']: 1
#
# L1:
# [' Kids Bedding']: 11
# [' Bed Skirts']: 11

# %%
pl = l  #THIS FUCNTION IS FILLED WITH FOR LOOPS TO CONTINUOUS CALCULATE Cs AND Ls beyond C1 AND L1 UNTIL THERE IS ONLY ONE COMBINATION LEFT
pos = 1
for count in range (2,1000):
    nc = set()
    temp = list(l)
    for i in range(0,len(temp)):
        for j in range(i+1,len(temp)):
            t = temp[i].union(temp[j])
            if(len(t) == count):
                nc.add(temp[i].union(temp[j]))
    nc = list(nc)
    c = Counter()
    for i in nc:
        c[i] = 0
        for q in db2:
            temp = set(q[1])
            if(i.issubset(temp)):
                c[i]+=1
    print("C"+str(count)+":")
    for i in c:
        print(str(list(i))+": "+str(c[i]))
    print()
    l = Counter()
    for i in c:
        if(c[i] >= s):
            l[i]+=c[i]
    print("L"+str(count)+":")
    for i in l:
        print(str(list(i))+": "+str(l[i]))
    print()
    if(len(l) == 0):
        break
    pl = l
    pos = count
print("Result: ")
print("L"+str(pos)+":")
for i in pl:
    print(str(list(i))+": "+str(pl[i]))
print()
from itertools import combinations
for l in pl:
    c = [frozenset(q) for q in combinations(l,len(l)-1)]
    mmax = 0
    for a in c:
        b = l-a
        ab = l
        sab = 0
        sa = 0
        sb = 0
        for q in db2:
            temp = set(q[1])
            if(a.issubset(temp)):
                sa+=1
            if(b.issubset(temp)):
                sb+=1
            if(ab.issubset(temp)):
                sab+=1
        temp = sab/sa*100
        if(temp > mmax):
            mmax = temp
        temp = sab/sb*100
        if(temp > mmax):
            mmax = temp
        print(str(list(a))+" -> "+str(list(b))+" = "+str(sab/sa*100)+"%")
        print(str(list(b))+" -> "+str(list(a))+" = "+str(sab/sb*100)+"%")
    curr = 1
    print("choosing:", end=' ')
    for a in c:
        b = l-a
        ab = l
        sab = 0
        sa = 0
        sb = 0
        for q in db2:
            temp = set(q[1])
            if(a.issubset(temp)):
                sa+=1
            if(b.issubset(temp)):
                sb+=1
            if(ab.issubset(temp)):
                sab+=1
        temp = sab/sa*100
        if(temp == mmax):
            print(curr, end = ' ')
        curr += 1
        temp = sab/sb*100
        if(temp == mmax):
            print(curr, end = ' ')
        curr += 1
    print()
    print()
# Out:
# C2:
# [' Kids Bedding', ' Bed Skirts']: 9
#
# L2:
#
# Result:
# L1:
# [' Kids Bedding']: 11
# [' Bed Skirts']: 11
#
# [] -> [' Kids Bedding'] = 55.00000000000001%
# [' Kids Bedding'] -> [] = 100.0%
# choosing: 2
#
# [] -> [' Bed Skirts'] = 55.00000000000001%
# [' Bed Skirts'] -> [] = 100.0%
# choosing: 2

# %%
from itertools import combinations
for l in pl:
    c = [frozenset(q) for q in combinations(l,len(l)-1)]
    mmax = 0
    for a in c:
        b = l-a
        ab = l
        sab = 0
        
        sa = 0
        sb = 0
        for q in db2:
            temp = set(q[1])
            if(a.issubset(temp)):
                sa+=1
            if(b.issubset(temp)):
                sb+=1
            if(ab.issubset(temp)):
                sab+=1
        temp = sab/sa*100
        if(temp > mmax):
            mmax = temp
        temp = sab/sb*100
        if(temp > mmax):
            mmax = temp
        print(str(list(a))+" -> "+str(list(b))+" = "+str(sab/sa*100)+"%")
        print(str(list(b))+" -> "+str(list(a))+" = "+str(sab/sb*100)+"%")
    curr = 1
    print("choosing:", end=' ')
    for a in c:
        b = l-a
        ab = l
        sab = 0
        sa = 0
        sb = 0
        for q in db2:
            temp = set(q[1])
            if(a.issubset(temp)):
                sa+=1
            if(b.issubset(temp)):
                sb+=1
            if(ab.issubset(temp)):
                sab+=1
        temp = sab/sa*100
        if(temp == mmax):
            print(curr, end = ' ')
        curr += 1
        temp = sab/sb*100
        if(temp == mmax):
            print(curr, end = ' ')
        curr += 1
    print()
    print()
# Out:
# [] -> [' Kids Bedding'] = 55.00000000000001%
# [' Kids Bedding'] -> [] = 100.0%
# choosing: 2
#
# [] -> [' Bed Skirts'] = 55.00000000000001%
# [' Bed Skirts'] -> [] = 100.0%
# choosing: 2
