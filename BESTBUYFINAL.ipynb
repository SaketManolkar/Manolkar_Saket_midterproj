# %%
from collections import defaultdict
import numpy as np
import pandas as pd
db = pd.read_csv("BestBuy_dataset.csv",header = None) #THIS FUNCTION IMPORTS THE CSV FILES!!
db.fillna('Zero')
# Out:
#          0                1                     2                  3   \
# 0    Trans1         Desk Top               Printer        Flash Drive
# 1    Trans2          Lab Top           Flash Drive   Microsoft Office
# 2    Trans3          Lab Top               Printer        Flash Drive
# 3    Trans4          Lab Top               Printer        Flash Drive
# 4    Trans5          Lab Top           Flash Drive       Lab Top Case
# 5    Trans6          Lab Top               Printer        Flash Drive
# 6    Trans7         Desk Top               Printer        Flash Drive
# 7    Trans8          Lab Top   External Hard-Drive         Anti-Virus
# 8    Trans9         Desk Top               Printer        Flash Drive
# 9   Trans10  Digital Camera                Lab Top           Desk Top
# 10  Trans11          Lab Top              Desk Top       Lab Top Case
# 11  Trans12  Digital Camera                Lab Top       Lab Top Case
# 12  Trans13  Digital Camera               Speakers               Zero
# 13  Trans14  Digital Camera               Desk Top            Printer
# 14  Trans15          Printer           Flash Drive   Microsoft Office
# 15  Trans16   Digital Camera           Flash Drive   Microsoft Office
# 16  Trans17  Digital Camera                Lab Top       Lab Top Case
# 17  Trans18  Digital Camera           Lab Top Case           Speakers
# 18  Trans19  Digital Camera                Lab Top            Printer
# 19  Trans20  Digital Camera                Lab Top           Speakers
#
#                       4                     5                     6   \
# 0       Microsoft Office              Speakers            Anti-Virus
# 1           Lab Top Case            Anti-Virus                  Zero
# 2       Microsoft Office            Anti-Virus          Lab Top Case
# 3             Anti-Virus   External Hard-Drive          Lab Top Case
# 4             Anti-Virus                  Zero                  Zero
# 5       Microsoft Office                  Zero                  Zero
# 6       Microsoft Office                  Zero                  Zero
# 7                   Zero                  Zero                  Zero
# 8       Microsoft Office          Lab Top Case            Anti-Virus
# 9                Printer           Flash Drive      Microsoft Office
# 10   External Hard-Drive              Speakers            Anti-Virus
# 11   External Hard-Drive            Anti-Virus              Speakers
# 12                  Zero                  Zero                  Zero
# 13           Flash Drive      Microsoft Office                  Zero
# 14            Anti-Virus          Lab Top Case              Speakers
# 15            Anti-Virus          Lab Top Case   External Hard-Drive
# 16                  Zero                  Zero                  Zero
# 17                  Zero                  Zero                  Zero
# 18           Flash Drive      Microsoft Office              Speakers
# 19            Anti-Virus          Lab Top Case                  Zero
#
#                       7                     8                     9   \
# 0                   Zero                  Zero                  Zero
# 1                   Zero                  Zero                  Zero
# 2    External Hard-Drive                  Zero                  Zero
# 3                   Zero                  Zero                  Zero
# 4                   Zero                  Zero                  Zero
# 5                   Zero                  Zero                  Zero
# 6                   Zero                  Zero                  Zero
# 7                   Zero                  Zero                  Zero
# 8               Speakers   External Hard-Drive                  Zero
# 9           Lab Top Case            Anti-Virus   External Hard-Drive
# 10                  Zero                  Zero                  Zero
# 11                  Zero                  Zero                  Zero
# 12                  Zero                  Zero                  Zero
# 13                  Zero                  Zero                  Zero
# 14   External Hard-Drive                  Zero                  Zero
# 15              Speakers                  Zero                  Zero
# 16                  Zero                  Zero                  Zero
# 17                  Zero                  Zero                  Zero
# 18          Lab Top Case            Anti-Virus                  Zero
# 19                  Zero                  Zero                  Zero
#
#            10
# 0        Zero
# 1        Zero
# 2        Zero
# 3        Zero
# 4        Zero
# 5        Zero
# 6        Zero
# 7        Zero
# 8        Zero
# 9    Speakers
# 10       Zero
# 11       Zero
# 12       Zero
# 13       Zero
# 14       Zero
# 15       Zero
# 16       Zero
# 17       Zero
# 18       Zero
# 19       Zero

# %%
db1 = db.values.tolist() #THIS FUCNTIONS CONVERTS CSV FILES INTO LISTS
db1
# Out:
# [['Trans1',
#   'Desk Top',
#   ' Printer',
#   ' Flash Drive',
#   ' Microsoft Office',
#   ' Speakers',
#   ' Anti-Virus',
#   nan,
#   nan,
#   nan,
#   nan],
#  ['Trans2',
#   'Lab Top',
#   ' Flash Drive',
#   ' Microsoft Office',
#   ' Lab Top Case',
#   ' Anti-Virus',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['Trans3',
#   'Lab Top',
#   ' Printer',
#   ' Flash Drive',
#   ' Microsoft Office',
#   ' Anti-Virus',
#   ' Lab Top Case',
#   ' External Hard-Drive',
#   nan,
#   nan,
#   nan],
#  ['Trans4',
#   'Lab Top',
#   ' Printer',
#   ' Flash Drive',
#   ' Anti-Virus',
#   ' External Hard-Drive',
#   ' Lab Top Case',
#   nan,
#   nan,
#   nan,
#   nan],
#  ['Trans5',
#   'Lab Top',
#   ' Flash Drive',
#   ' Lab Top Case',
#   ' Anti-Virus',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['Trans6',
#   'Lab Top',
#   ' Printer',
#   ' Flash Drive',
#   ' Microsoft Office',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['Trans7',
#   'Desk Top',
#   ' Printer',
#   ' Flash Drive',
#   ' Microsoft Office',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['Trans8',
#   'Lab Top',
#   ' External Hard-Drive',
#   ' Anti-Virus',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['Trans9',
#   'Desk Top',
#   ' Printer',
#   ' Flash Drive',
#   ' Microsoft Office',
#   ' Lab Top Case',
#   ' Anti-Virus',
#   ' Speakers',
#   ' External Hard-Drive',
#   nan,
#   nan],
#  ['Trans10',
#   'Digital Camera ',
#   ' Lab Top',
#   ' Desk Top',
#   ' Printer',
#   ' Flash Drive',
#   ' Microsoft Office',
#   ' Lab Top Case',
#   ' Anti-Virus',
#   ' External Hard-Drive',
#   ' Speakers'],
#  ['Trans11',
#   'Lab Top',
#   ' Desk Top',
#   ' Lab Top Case',
#   ' External Hard-Drive',
#   ' Speakers',
#   ' Anti-Virus',
#   nan,
#   nan,
#   nan,
#   nan],
#  ['Trans12',
#   'Digital Camera ',
#   ' Lab Top',
#   ' Lab Top Case',
#   ' External Hard-Drive',
#   ' Anti-Virus',
#   ' Speakers',
#   nan,
#   nan,
#   nan,
#   nan],
#  ['Trans13',
#   'Digital Camera ',
#   ' Speakers',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['Trans14',
#   'Digital Camera ',
#   ' Desk Top',
#   ' Printer',
#   ' Flash Drive',
#   ' Microsoft Office',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['Trans15',
#   'Printer',
#   ' Flash Drive',
#   ' Microsoft Office',
#   ' Anti-Virus',
#   ' Lab Top Case',
#   ' Speakers',
#   ' External Hard-Drive',
#   nan,
#   nan,
#   nan],
#  ['Trans16',
#   'Digital Camera',
#   ' Flash Drive',
#   ' Microsoft Office',
#   ' Anti-Virus',
#   ' Lab Top Case',
#   ' External Hard-Drive',
#   ' Speakers',
#   nan,
#   nan,
#   nan],
#  ['Trans17',
#   'Digital Camera ',
#   ' Lab Top',
#   ' Lab Top Case',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['Trans18',
#   'Digital Camera ',
#   ' Lab Top Case',
#   ' Speakers',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['Trans19',
#   'Digital Camera ',
#   ' Lab Top',
#   ' Printer',
#   ' Flash Drive',
#   ' Microsoft Office',
#   ' Speakers',
#   ' Lab Top Case',
#   ' Anti-Virus',
#   nan,
#   nan],
#  ['Trans20',
#   'Digital Camera ',
#   ' Lab Top',
#   ' Speakers',
#   ' Anti-Virus',
#   ' Lab Top Case',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan]]

# %%
for i in range(0,len(db1)): #WITH THIS FUNCTION WE CONVERT SIMPLE LISTS INTO NESTED LIST, 
                            #NESTED LISTS ARE EASIER TO PROCESS WITH THIS ALGORITHM 
    new_line=db1[i][0]
    new_line1= db1[i][1:]
    db2=[]
    db2.append(new_line)
    db2.append(new_line1)
    print(db2)
# Out:
# ['Trans1', ['Desk Top', ' Printer', ' Flash Drive', ' Microsoft Office', ' Speakers', ' Anti-Virus', nan, nan, nan, nan]]
# ['Trans2', ['Lab Top', ' Flash Drive', ' Microsoft Office', ' Lab Top Case', ' Anti-Virus', nan, nan, nan, nan, nan]]
# ['Trans3', ['Lab Top', ' Printer', ' Flash Drive', ' Microsoft Office', ' Anti-Virus', ' Lab Top Case', ' External Hard-Drive', nan, nan, nan]]
# ['Trans4', ['Lab Top', ' Printer', ' Flash Drive', ' Anti-Virus', ' External Hard-Drive', ' Lab Top Case', nan, nan, nan, nan]]
# ['Trans5', ['Lab Top', ' Flash Drive', ' Lab Top Case', ' Anti-Virus', nan, nan, nan, nan, nan, nan]]
# ['Trans6', ['Lab Top', ' Printer', ' Flash Drive', ' Microsoft Office', nan, nan, nan, nan, nan, nan]]
# ['Trans7', ['Desk Top', ' Printer', ' Flash Drive', ' Microsoft Office', nan, nan, nan, nan, nan, nan]]
# ['Trans8', ['Lab Top', ' External Hard-Drive', ' Anti-Virus', nan, nan, nan, nan, nan, nan, nan]]
# ['Trans9', ['Desk Top', ' Printer', ' Flash Drive', ' Microsoft Office', ' Lab Top Case', ' Anti-Virus', ' Speakers', ' External Hard-Drive', nan, nan]]
# ['Trans10', ['Digital Camera ', ' Lab Top', ' Desk Top', ' Printer', ' Flash Drive', ' Microsoft Office', ' Lab Top Case', ' Anti-Virus', ' External Hard-Drive', ' Speakers']]
# ['Trans11', ['Lab Top', ' Desk Top', ' Lab Top Case', ' External Hard-Drive', ' Speakers', ' Anti-Virus', nan, nan, nan, nan]]
# ['Trans12', ['Digital Camera ', ' Lab Top', ' Lab Top Case', ' External Hard-Drive', ' Anti-Virus', ' Speakers', nan, nan, nan, nan]]
# ['Trans13', ['Digital Camera ', ' Speakers', nan, nan, nan, nan, nan, nan, nan, nan]]
# ['Trans14', ['Digital Camera ', ' Desk Top', ' Printer', ' Flash Drive', ' Microsoft Office', nan, nan, nan, nan, nan]]
# ['Trans15', ['Printer', ' Flash Drive', ' Microsoft Office', ' Anti-Virus', ' Lab Top Case', ' Speakers', ' External Hard-Drive', nan, nan, nan]]
# ['Trans16', ['Digital Camera', ' Flash Drive', ' Microsoft Office', ' Anti-Virus', ' Lab Top Case', ' External Hard-Drive', ' Speakers', nan, nan, nan]]
# ['Trans17', ['Digital Camera ', ' Lab Top', ' Lab Top Case', nan, nan, nan, nan, nan, nan, nan]]
# ['Trans18', ['Digital Camera ', ' Lab Top Case', ' Speakers', nan, nan, nan, nan, nan, nan, nan]]
# ['Trans19', ['Digital Camera ', ' Lab Top', ' Printer', ' Flash Drive', ' Microsoft Office', ' Speakers', ' Lab Top Case', ' Anti-Virus', nan, nan]]
# ['Trans20', ['Digital Camera ', ' Lab Top', ' Speakers', ' Anti-Virus', ' Lab Top Case', nan, nan, nan, nan, nan]]

# %%
db2 = [['Trans1', ['Desk Top', ' Printer', ' Flash Drive', ' Microsoft Office', ' Speakers', ' Anti-Virus']]
,['Trans2', ['Lab Top', ' Flash Drive', ' Microsoft Office', ' Lab Top Case', ' Anti-Virus']]
,['Trans3', ['Lab Top', ' Printer', ' Flash Drive', ' Microsoft Office', ' Anti-Virus', ' Lab Top Case', ' External Hard-Drive']]
,['Trans4', ['Lab Top', ' Printer', ' Flash Drive', ' Anti-Virus', ' External Hard-Drive', ' Lab Top Case']]
,['Trans5', ['Lab Top', ' Flash Drive', ' Lab Top Case', ' Anti-Virus']]
,['Trans6', ['Lab Top', ' Printer', ' Flash Drive', ' Microsoft Office']]
,['Trans7', ['Desk Top', ' Printer', ' Flash Drive', ' Microsoft Office']]
,['Trans8', ['Lab Top', ' External Hard-Drive', ' Anti-Virus']]
,['Trans9', ['Desk Top', ' Printer', ' Flash Drive', ' Microsoft Office', ' Lab Top Case', ' Anti-Virus', ' Speakers', ' External Hard-Drive']]
,['Trans10', ['Digital Camera ', ' Lab Top', ' Desk Top', ' Printer', ' Flash Drive', ' Microsoft Office', ' Lab Top Case', ' Anti-Virus', ' External Hard-Drive', ' Speakers']]
,['Trans11', ['Lab Top', ' Desk Top', ' Lab Top Case', ' External Hard-Drive', ' Speakers', ' Anti-Virus']]
,['Trans12', ['Digital Camera ', ' Lab Top', ' Lab Top Case', ' External Hard-Drive', ' Anti-Virus', ' Speakers']]
,['Trans13', ['Digital Camera ', ' Speakers']]
,['Trans14', ['Digital Camera ', ' Desk Top', ' Printer', ' Flash Drive', ' Microsoft Office']]
,['Trans15', ['Printer', ' Flash Drive', ' Microsoft Office', ' Anti-Virus', ' Lab Top Case', ' Speakers', ' External Hard-Drive']]
,['Trans16', ['Digital Camera', ' Flash Drive', ' Microsoft Office', ' Anti-Virus', ' Lab Top Case', ' External Hard-Drive', ' Speakers']]
,['Trans17', ['Digital Camera ', ' Lab Top', ' Lab Top Case']]
,['Trans18', ['Digital Camera ', ' Lab Top Case', ' Speakers']]
,['Trans19', ['Digital Camera ', ' Lab Top', ' Printer', ' Flash Drive', ' Microsoft Office', ' Speakers', ' Lab Top Case', ' Anti-Virus']]
,['Trans20', ['Digital Camera ', ' Lab Top', ' Speakers', ' Anti-Virus', ' Lab Top Case']]]

# %%
 print(db2) #FOLLOWING IS A NESTED LIST
# Out:
# [['Trans1', ['Desk Top', ' Printer', ' Flash Drive', ' Microsoft Office', ' Speakers', ' Anti-Virus']], ['Trans2', ['Lab Top', ' Flash Drive', ' Microsoft Office', ' Lab Top Case', ' Anti-Virus']], ['Trans3', ['Lab Top', ' Printer', ' Flash Drive', ' Microsoft Office', ' Anti-Virus', ' Lab Top Case', ' External Hard-Drive']], ['Trans4', ['Lab Top', ' Printer', ' Flash Drive', ' Anti-Virus', ' External Hard-Drive', ' Lab Top Case']], ['Trans5', ['Lab Top', ' Flash Drive', ' Lab Top Case', ' Anti-Virus']], ['Trans6', ['Lab Top', ' Printer', ' Flash Drive', ' Microsoft Office']], ['Trans7', ['Desk Top', ' Printer', ' Flash Drive', ' Microsoft Office']], ['Trans8', ['Lab Top', ' External Hard-Drive', ' Anti-Virus']], ['Trans9', ['Desk Top', ' Printer', ' Flash Drive', ' Microsoft Office', ' Lab Top Case', ' Anti-Virus', ' Speakers', ' External Hard-Drive']], ['Trans10', ['Digital Camera ', ' Lab Top', ' Desk Top', ' Printer', ' Flash Drive', ' Microsoft Office', ' Lab Top Case', ' Anti-Virus', ' External Hard-Drive', ' Speakers']], ['Trans11', ['Lab Top', ' Desk Top', ' Lab Top Case', ' External Hard-Drive', ' Speakers', ' Anti-Virus']], ['Trans12', ['Digital Camera ', ' Lab Top', ' Lab Top Case', ' External Hard-Drive', ' Anti-Virus', ' Speakers']], ['Trans13', ['Digital Camera ', ' Speakers']], ['Trans14', ['Digital Camera ', ' Desk Top', ' Printer', ' Flash Drive', ' Microsoft Office']], ['Trans15', ['Printer', ' Flash Drive', ' Microsoft Office', ' Anti-Virus', ' Lab Top Case', ' Speakers', ' External Hard-Drive']], ['Trans16', ['Digital Camera', ' Flash Drive', ' Microsoft Office', ' Anti-Virus', ' Lab Top Case', ' External Hard-Drive', ' Speakers']], ['Trans17', ['Digital Camera ', ' Lab Top', ' Lab Top Case']], ['Trans18', ['Digital Camera ', ' Lab Top Case', ' Speakers']], ['Trans19', ['Digital Camera ', ' Lab Top', ' Printer', ' Flash Drive', ' Microsoft Office', ' Speakers', ' Lab Top Case', ' Anti-Virus']], ['Trans20', ['Digital Camera ', ' Lab Top', ' Speakers', ' Anti-Virus', ' Lab Top Case']]]

# %%
init = []      # THIS FUNCTION SPECIFIES ALL THE INDIVISUAL ITEMSETS IN THE TRANSACTIONS
for i in db2:
    for q in i[1]:
        if(q not in init):
            init.append(q)

print(init)
# Out:
# ['Desk Top', ' Printer', ' Flash Drive', ' Microsoft Office', ' Speakers', ' Anti-Virus', 'Lab Top', ' Lab Top Case', ' External Hard-Drive', 'Digital Camera ', ' Lab Top', ' Desk Top', 'Printer', 'Digital Camera']

# %%
support = 0.70
s = int(support*len(init))

# %%
from collections import Counter #THIS FUCNTION CALCULATES C1 AND L1 WITH RESPECT TO MINIMUM SUPPORT
c = Counter()
for i in init:
    for d in db2:
        if(i in d[1]):
            c[i]+=1
print("C1:")
for i in c:
    print(str([i])+": "+str(c[i]))
print()
l = Counter()
for i in c:
    if(c[i] >= s):
        l[frozenset([i])]+=c[i]
print("L1:")
for i in l:
    print(str(list(i))+": "+str(l[i]))
print()
# Out:
# C1:
# ['Desk Top']: 3
# [' Printer']: 9
# [' Flash Drive']: 13
# [' Microsoft Office']: 11
# [' Speakers']: 11
# [' Anti-Virus']: 14
# ['Lab Top']: 7
# [' Lab Top Case']: 14
# [' External Hard-Drive']: 9
# ['Digital Camera ']: 8
# [' Lab Top']: 5
# [' Desk Top']: 3
# ['Printer']: 1
# ['Digital Camera']: 1
#
# L1:
# [' Printer']: 9
# [' Flash Drive']: 13
# [' Microsoft Office']: 11
# [' Speakers']: 11
# [' Anti-Virus']: 14
# [' Lab Top Case']: 14
# [' External Hard-Drive']: 9

# %%
pl = l  #THIS FUCNTION IS FILLED WITH FOR LOOPS TO CONTINUOUS CALCULATE Cs AND Ls beyond C1 AND L1 UNTIL THERE IS ONLY ONE COMBINATION LEFT
pos = 1
for count in range (2,1000):
    nc = set()
    temp = list(l)
    for i in range(0,len(temp)):
        for j in range(i+1,len(temp)):
            t = temp[i].union(temp[j])
            if(len(t) == count):
                nc.add(temp[i].union(temp[j]))
    nc = list(nc)
    c = Counter()
    for i in nc:
        c[i] = 0
        for q in db2:
            temp = set(q[1])
            if(i.issubset(temp)):
                c[i]+=1
    print("C"+str(count)+":")
    for i in c:
        print(str(list(i))+": "+str(c[i]))
    print()
    l = Counter()
    for i in c:
        if(c[i] >= s):
            l[i]+=c[i]
    print("L"+str(count)+":")
    for i in l:
        print(str(list(i))+": "+str(l[i]))
    print()
    if(len(l) == 0):
        break
    pl = l
    pos = count
print("Result: ")
print("L"+str(pos)+":")
for i in pl:
    print(str(list(i))+": "+str(pl[i]))
print()
from itertools import combinations
for l in pl:
    c = [frozenset(q) for q in combinations(l,len(l)-1)]
    mmax = 0
    for a in c:
        b = l-a
        ab = l
        sab = 0
        sa = 0
        sb = 0
        for q in db2:
            temp = set(q[1])
            if(a.issubset(temp)):
                sa+=1
            if(b.issubset(temp)):
                sb+=1
            if(ab.issubset(temp)):
                sab+=1
        temp = sab/sa*100
        if(temp > mmax):
            mmax = temp
        temp = sab/sb*100
        if(temp > mmax):
            mmax = temp
        print(str(list(a))+" -> "+str(list(b))+" = "+str(sab/sa*100)+"%")
        print(str(list(b))+" -> "+str(list(a))+" = "+str(sab/sb*100)+"%")
    curr = 1
    print("choosing:", end=' ')
    for a in c:
        b = l-a
        ab = l
        sab = 0
        sa = 0
        sb = 0
        for q in db2:
            temp = set(q[1])
            if(a.issubset(temp)):
                sa+=1
            if(b.issubset(temp)):
                sb+=1
            if(ab.issubset(temp)):
                sab+=1
        temp = sab/sa*100
        if(temp == mmax):
            print(curr, end = ' ')
        curr += 1
        temp = sab/sb*100
        if(temp == mmax):
            print(curr, end = ' ')
        curr += 1
    print()
    print()
# Out:
# C2:
# [' Printer', ' Speakers']: 4
# [' Anti-Virus', ' Speakers']: 9
# [' Flash Drive', ' Lab Top Case']: 9
# [' Flash Drive', ' Anti-Virus']: 10
# [' External Hard-Drive', ' Microsoft Office']: 5
# [' External Hard-Drive', ' Printer']: 4
# [' Printer', ' Anti-Virus']: 6
# [' Lab Top Case', ' Printer']: 5
# [' External Hard-Drive', ' Lab Top Case']: 8
# [' Lab Top Case', ' Microsoft Office']: 7
# [' External Hard-Drive', ' Flash Drive']: 6
# [' Microsoft Office', ' Printer']: 8
# [' Microsoft Office', ' Anti-Virus']: 8
# [' Flash Drive', ' Speakers']: 6
# [' Lab Top Case', ' Anti-Virus']: 12
# [' Lab Top Case', ' Speakers']: 9
# [' Flash Drive', ' Printer']: 9
# [' Microsoft Office', ' Speakers']: 6
# [' External Hard-Drive', ' Speakers']: 6
# [' External Hard-Drive', ' Anti-Virus']: 9
# [' Flash Drive', ' Microsoft Office']: 11
#
# L2:
# [' Anti-Virus', ' Speakers']: 9
# [' Flash Drive', ' Lab Top Case']: 9
# [' Flash Drive', ' Anti-Virus']: 10
# [' Lab Top Case', ' Anti-Virus']: 12
# [' Lab Top Case', ' Speakers']: 9
# [' Flash Drive', ' Printer']: 9
# [' External Hard-Drive', ' Anti-Virus']: 9
# [' Flash Drive', ' Microsoft Office']: 11
#
# C3:
# [' Flash Drive', ' Microsoft Office', ' Anti-Virus']: 8
# [' Flash Drive', ' Lab Top Case', ' Speakers']: 5
# [' Anti-Virus', ' Lab Top Case', ' Speakers']: 8
# [' Flash Drive', ' Printer', ' Anti-Virus']: 6
# [' External Hard-Drive', ' Flash Drive', ' Anti-Virus']: 6
# [' Flash Drive', ' Microsoft Office', ' Printer']: 8
# [' Flash Drive', ' Lab Top Case', ' Anti-Virus']: 9
# [' External Hard-Drive', ' Lab Top Case', ' Anti-Virus']: 8
# [' Microsoft Office', ' Flash Drive', ' Lab Top Case']: 7
# [' Flash Drive', ' Lab Top Case', ' Printer']: 5
# [' Anti-Virus', ' External Hard-Drive', ' Speakers']: 6
# [' Anti-Virus', ' Flash Drive', ' Speakers']: 6
#
# L3:
# [' Flash Drive', ' Lab Top Case', ' Anti-Virus']: 9
#
# C4:
#
# L4:
#
# Result:
# L3:
# [' Flash Drive', ' Lab Top Case', ' Anti-Virus']: 9
#
# [' Flash Drive', ' Lab Top Case'] -> [' Anti-Virus'] = 100.0%
# [' Anti-Virus'] -> [' Flash Drive', ' Lab Top Case'] = 64.28571428571429%
# [' Flash Drive', ' Anti-Virus'] -> [' Lab Top Case'] = 90.0%
# [' Lab Top Case'] -> [' Flash Drive', ' Anti-Virus'] = 64.28571428571429%
# [' Lab Top Case', ' Anti-Virus'] -> [' Flash Drive'] = 75.0%
# [' Flash Drive'] -> [' Lab Top Case', ' Anti-Virus'] = 69.23076923076923%
# choosing: 1

# %%
from itertools import combinations
for l in pl:
    c = [frozenset(q) for q in combinations(l,len(l)-1)]
    mmax = 0
    for a in c:
        b = l-a
        ab = l
        sab = 0
        
        sa = 0
        sb = 0
        for q in db2:
            temp = set(q[1])
            if(a.issubset(temp)):
                sa+=1
            if(b.issubset(temp)):
                sb+=1
            if(ab.issubset(temp)):
                sab+=1
        temp = sab/sa*100
        if(temp > mmax):
            mmax = temp
        temp = sab/sb*100
        if(temp > mmax):
            mmax = temp
        print(str(list(a))+" -> "+str(list(b))+" = "+str(sab/sa*100)+"%")
        print(str(list(b))+" -> "+str(list(a))+" = "+str(sab/sb*100)+"%")
    curr = 1
    print("choosing:", end=' ')
    for a in c:
        b = l-a
        ab = l
        sab = 0
        sa = 0
        sb = 0
        for q in db2:
            temp = set(q[1])
            if(a.issubset(temp)):
                sa+=1
            if(b.issubset(temp)):
                sb+=1
            if(ab.issubset(temp)):
                sab+=1
        temp = sab/sa*100
        if(temp == mmax):
            print(curr, end = ' ')
        curr += 1
        temp = sab/sb*100
        if(temp == mmax):
            print(curr, end = ' ')
        curr += 1
    print()
    print()
# Out:
# [' Flash Drive', ' Lab Top Case'] -> [' Anti-Virus'] = 100.0%
# [' Anti-Virus'] -> [' Flash Drive', ' Lab Top Case'] = 64.28571428571429%
# [' Flash Drive', ' Anti-Virus'] -> [' Lab Top Case'] = 90.0%
# [' Lab Top Case'] -> [' Flash Drive', ' Anti-Virus'] = 64.28571428571429%
# [' Lab Top Case', ' Anti-Virus'] -> [' Flash Drive'] = 75.0%
# [' Flash Drive'] -> [' Lab Top Case', ' Anti-Virus'] = 69.23076923076923%
# choosing: 1
