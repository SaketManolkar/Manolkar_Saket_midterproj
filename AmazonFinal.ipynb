# %%
from collections import defaultdict
import numpy as np
import pandas as pd
db = pd.read_csv("Amazon_dataset.csv",header = None) #THIS FUNCTION IMPORTS THE CSV FILES!!
db.fillna('Zero')
# Out:
#           0                                        1  \
# 0    Trans1                       A Beginner’s Guide
# 1    Trans2                       A Beginner’s Guide
# 2    Trans3                       A Beginner’s Guide
# 3    Trans4  Android Programming: The Big Nerd Ranch
# 4    Trans5  Android Programming: The Big Nerd Ranch
# 5    Trans6                       A Beginner’s Guide
# 6    Trans7                       A Beginner’s Guide
# 7    Trans8             Java: The Complete Reference
# 8    Trans9                         Java For Dummies
# 9   Trans10          Beginning Programming with Java
# 10  Trans11                       A Beginner’s Guide
# 11  Trans12                       A Beginner’s Guide
# 12  Trans13                       A Beginner’s Guide
# 13  Trans14                         Java For Dummies
# 14  Trans15                         Java For Dummies
# 15  Trans16                       A Beginner’s Guide
# 16  Trans17                       A Beginner’s Guide
# 17  Trans18             Head First Java 2nd Edition
# 18  Trans19  Android Programming: The Big Nerd Ranch
# 19  Trans20                       A Beginner’s Guide
#
#                                            2  \
# 0               Java: The Complete Reference
# 1               Java: The Complete Reference
# 2               Java: The Complete Reference
# 3               Head First Java 2nd Edition
# 4            Beginning Programming with Java
# 5    Android Programming: The Big Nerd Ranch
# 6               Head First Java 2nd Edition
# 7                           Java For Dummies
# 8    Android Programming: The Big Nerd Ranch
# 9                        Java 8 Pocket Guide
# 10              Java: The Complete Reference
# 11              Java: The Complete Reference
# 12              Java: The Complete Reference
# 13   Android Programming: The Big Nerd Ranch
# 14   Android Programming: The Big Nerd Ranch
# 15              Java: The Complete Reference
# 16              Java: The Complete Reference
# 17           Beginning Programming with Java
# 18               Head First Java 2nd Edition
# 19              Java: The Complete Reference
#
#                                            3  \
# 0                           Java For Dummies
# 1                           Java For Dummies
# 2                           Java For Dummies
# 3            Beginning Programming with Java
# 4                        Java 8 Pocket Guide
# 5                Head First Java 2nd Edition
# 6            Beginning Programming with Java
# 7    Android Programming: The Big Nerd Ranch
# 8               Head First Java 2nd Edition
# 9              C++ Programming in Easy Steps
# 10                          Java For Dummies
# 11                          Java For Dummies
# 12                          Java For Dummies
# 13               Head First Java 2nd Edition
# 14                                      Zero
# 15                          Java For Dummies
# 16                          Java For Dummies
# 17                       Java 8 Pocket Guide
# 18                                      Zero
# 19                          Java For Dummies
#
#                                            4  \
# 0    Android Programming: The Big Nerd Ranch
# 1                                       Zero
# 2    Android Programming: The Big Nerd Ranch
# 3                                       Zero
# 4                                       Zero
# 5                                       Zero
# 6                                       Zero
# 7                                       Zero
# 8            Beginning Programming with Java
# 9                                       Zero
# 10   Android Programming: The Big Nerd Ranch
# 11   HTML and CSS: Design and Build Websites
# 12                       Java 8 Pocket Guide
# 13                                      Zero
# 14                                      Zero
# 15   Android Programming: The Big Nerd Ranch
# 16   Android Programming: The Big Nerd Ranch
# 17                                      Zero
# 18                                      Zero
# 19                                      Zero
#
#                                            5
# 0                                       Zero
# 1                                       Zero
# 2                Head First Java 2nd Edition
# 3                                       Zero
# 4                                       Zero
# 5                                       Zero
# 6                                       Zero
# 7                                       Zero
# 8                                       Zero
# 9                                       Zero
# 10                                      Zero
# 11                                      Zero
# 12   HTML and CSS: Design and Build Websites
# 13                                      Zero
# 14                                      Zero
# 15                                      Zero
# 16                                      Zero
# 17                                      Zero
# 18                                      Zero
# 19                                      Zero

# %%
db1 = db.values.tolist() #THIS FUCNTIONS CONVERTS CSV FILES INTO LISTS
db1
# Out:
# [['Trans1',
#   'A Beginner’s Guide',
#   ' Java: The Complete Reference',
#   ' Java For Dummies',
#   ' Android Programming: The Big Nerd Ranch',
#   nan],
#  ['Trans2',
#   'A Beginner’s Guide',
#   ' Java: The Complete Reference',
#   ' Java For Dummies',
#   nan,
#   nan],
#  ['Trans3',
#   'A Beginner’s Guide',
#   ' Java: The Complete Reference',
#   ' Java For Dummies',
#   ' Android Programming: The Big Nerd Ranch',
#   ' Head First Java 2nd Edition'],
#  ['Trans4',
#   'Android Programming: The Big Nerd Ranch',
#   ' Head First Java 2nd Edition ',
#   ' Beginning Programming with Java',
#   nan,
#   nan],
#  ['Trans5',
#   'Android Programming: The Big Nerd Ranch',
#   ' Beginning Programming with Java',
#   ' Java 8 Pocket Guide',
#   nan,
#   nan],
#  ['Trans6',
#   'A Beginner’s Guide',
#   ' Android Programming: The Big Nerd Ranch',
#   ' Head First Java 2nd Edition',
#   nan,
#   nan],
#  ['Trans7',
#   'A Beginner’s Guide',
#   ' Head First Java 2nd Edition ',
#   ' Beginning Programming with Java',
#   nan,
#   nan],
#  ['Trans8',
#   'Java: The Complete Reference',
#   ' Java For Dummies',
#   ' Android Programming: The Big Nerd Ranch',
#   nan,
#   nan],
#  ['Trans9',
#   'Java For Dummies',
#   ' Android Programming: The Big Nerd Ranch',
#   ' Head First Java 2nd Edition ',
#   ' Beginning Programming with Java',
#   nan],
#  ['Trans10',
#   'Beginning Programming with Java',
#   ' Java 8 Pocket Guide',
#   ' C++ Programming in Easy Steps',
#   nan,
#   nan],
#  ['Trans11',
#   'A Beginner’s Guide',
#   ' Java: The Complete Reference',
#   ' Java For Dummies',
#   ' Android Programming: The Big Nerd Ranch',
#   nan],
#  ['Trans12',
#   'A Beginner’s Guide',
#   ' Java: The Complete Reference',
#   ' Java For Dummies',
#   ' HTML and CSS: Design and Build Websites',
#   nan],
#  ['Trans13',
#   'A Beginner’s Guide',
#   ' Java: The Complete Reference',
#   ' Java For Dummies',
#   ' Java 8 Pocket Guide',
#   ' HTML and CSS: Design and Build Websites'],
#  ['Trans14',
#   'Java For Dummies',
#   ' Android Programming: The Big Nerd Ranch',
#   ' Head First Java 2nd Edition',
#   nan,
#   nan],
#  ['Trans15',
#   'Java For Dummies',
#   ' Android Programming: The Big Nerd Ranch',
#   nan,
#   nan,
#   nan],
#  ['Trans16',
#   'A Beginner’s Guide',
#   ' Java: The Complete Reference',
#   ' Java For Dummies',
#   ' Android Programming: The Big Nerd Ranch',
#   nan],
#  ['Trans17',
#   'A Beginner’s Guide',
#   ' Java: The Complete Reference',
#   ' Java For Dummies',
#   ' Android Programming: The Big Nerd Ranch',
#   nan],
#  ['Trans18',
#   'Head First Java 2nd Edition ',
#   ' Beginning Programming with Java',
#   ' Java 8 Pocket Guide',
#   nan,
#   nan],
#  ['Trans19',
#   'Android Programming: The Big Nerd Ranch',
#   ' Head First Java 2nd Edition',
#   nan,
#   nan,
#   nan],
#  ['Trans20',
#   'A Beginner’s Guide',
#   ' Java: The Complete Reference',
#   ' Java For Dummies',
#   nan,
#   nan]]

# %%
for i in range(0,len(db1)): #WITH THIS FUNCTION WE CONVERT SIMPLE LISTS INTO NESTED LIST, 
                            #NESTED LISTS ARE EASIER TO PROCESS WITH THIS ALGORITHM 
    new_line=db1[i][0]
    new_line1= db1[i][1:]
    db2=[]
    db2.append(new_line)
    db2.append(new_line1)
    print(db2)
# Out:
# ['Trans1', ['A Beginner’s Guide', ' Java: The Complete Reference', ' Java For Dummies', ' Android Programming: The Big Nerd Ranch', nan]]
# ['Trans2', ['A Beginner’s Guide', ' Java: The Complete Reference', ' Java For Dummies', nan, nan]]
# ['Trans3', ['A Beginner’s Guide', ' Java: The Complete Reference', ' Java For Dummies', ' Android Programming: The Big Nerd Ranch', ' Head First Java 2nd Edition']]
# ['Trans4', ['Android Programming: The Big Nerd Ranch', ' Head First Java 2nd Edition ', ' Beginning Programming with Java', nan, nan]]
# ['Trans5', ['Android Programming: The Big Nerd Ranch', ' Beginning Programming with Java', ' Java 8 Pocket Guide', nan, nan]]
# ['Trans6', ['A Beginner’s Guide', ' Android Programming: The Big Nerd Ranch', ' Head First Java 2nd Edition', nan, nan]]
# ['Trans7', ['A Beginner’s Guide', ' Head First Java 2nd Edition ', ' Beginning Programming with Java', nan, nan]]
# ['Trans8', ['Java: The Complete Reference', ' Java For Dummies', ' Android Programming: The Big Nerd Ranch', nan, nan]]
# ['Trans9', ['Java For Dummies', ' Android Programming: The Big Nerd Ranch', ' Head First Java 2nd Edition ', ' Beginning Programming with Java', nan]]
# ['Trans10', ['Beginning Programming with Java', ' Java 8 Pocket Guide', ' C++ Programming in Easy Steps', nan, nan]]
# ['Trans11', ['A Beginner’s Guide', ' Java: The Complete Reference', ' Java For Dummies', ' Android Programming: The Big Nerd Ranch', nan]]
# ['Trans12', ['A Beginner’s Guide', ' Java: The Complete Reference', ' Java For Dummies', ' HTML and CSS: Design and Build Websites', nan]]
# ['Trans13', ['A Beginner’s Guide', ' Java: The Complete Reference', ' Java For Dummies', ' Java 8 Pocket Guide', ' HTML and CSS: Design and Build Websites']]
# ['Trans14', ['Java For Dummies', ' Android Programming: The Big Nerd Ranch', ' Head First Java 2nd Edition', nan, nan]]
# ['Trans15', ['Java For Dummies', ' Android Programming: The Big Nerd Ranch', nan, nan, nan]]
# ['Trans16', ['A Beginner’s Guide', ' Java: The Complete Reference', ' Java For Dummies', ' Android Programming: The Big Nerd Ranch', nan]]
# ['Trans17', ['A Beginner’s Guide', ' Java: The Complete Reference', ' Java For Dummies', ' Android Programming: The Big Nerd Ranch', nan]]
# ['Trans18', ['Head First Java 2nd Edition ', ' Beginning Programming with Java', ' Java 8 Pocket Guide', nan, nan]]
# ['Trans19', ['Android Programming: The Big Nerd Ranch', ' Head First Java 2nd Edition', nan, nan, nan]]
# ['Trans20', ['A Beginner’s Guide', ' Java: The Complete Reference', ' Java For Dummies', nan, nan]]

# %%
db2 =[['Trans1', ['A Beginner’s Guide', ' Java: The Complete Reference', ' Java For Dummies', ' Android Programming: The Big Nerd Ranch']]
,['Trans2', ['A Beginner’s Guide', ' Java: The Complete Reference', ' Java For Dummies']]
,['Trans3', ['A Beginner’s Guide', ' Java: The Complete Reference', ' Java For Dummies', ' Android Programming: The Big Nerd Ranch', ' Head First Java 2nd Edition']]
,['Trans4', ['Android Programming: The Big Nerd Ranch', ' Head First Java 2nd Edition ', ' Beginning Programming with Java']]
,['Trans5', ['Android Programming: The Big Nerd Ranch', ' Beginning Programming with Java', ' Java 8 Pocket Guide']]
,['Trans6', ['A Beginner’s Guide', ' Android Programming: The Big Nerd Ranch', ' Head First Java 2nd Edition']]
,['Trans7', ['A Beginner’s Guide', ' Head First Java 2nd Edition ', ' Beginning Programming with Java']]
,['Trans8', ['Java: The Complete Reference', ' Java For Dummies', ' Android Programming: The Big Nerd Ranch']]
,['Trans9', ['Java For Dummies', ' Android Programming: The Big Nerd Ranch', ' Head First Java 2nd Edition ', ' Beginning Programming with Java']]
,['Trans10', ['Beginning Programming with Java', ' Java 8 Pocket Guide', ' C++ Programming in Easy Steps']]
,['Trans11', ['A Beginner’s Guide', ' Java: The Complete Reference', ' Java For Dummies', ' Android Programming: The Big Nerd Ranch']]
,['Trans12', ['A Beginner’s Guide', ' Java: The Complete Reference', ' Java For Dummies', ' HTML and CSS: Design and Build Websites']]
,['Trans13', ['A Beginner’s Guide', ' Java: The Complete Reference', ' Java For Dummies', ' Java 8 Pocket Guide', ' HTML and CSS: Design and Build Websites']]
,['Trans14', ['Java For Dummies', ' Android Programming: The Big Nerd Ranch', ' Head First Java 2nd Edition']]
,['Trans15', ['Java For Dummies', ' Android Programming: The Big Nerd Ranch']]
,['Trans16', ['A Beginner’s Guide', ' Java: The Complete Reference', ' Java For Dummies', ' Android Programming: The Big Nerd Ranch']]
,['Trans17', ['A Beginner’s Guide', ' Java: The Complete Reference', ' Java For Dummies', ' Android Programming: The Big Nerd Ranch']]
,['Trans18', ['Head First Java 2nd Edition ', ' Beginning Programming with Java', ' Java 8 Pocket Guide']]
,['Trans19', ['Android Programming: The Big Nerd Ranch', ' Head First Java 2nd Edition']]
,['Trans20', ['A Beginner’s Guide', ' Java: The Complete Reference', ' Java For Dummies']]]

# %%
 print(db2) #FOLLOWING IS A NESTED LIST
# Out:
# [['Trans1', ['A Beginner’s Guide', ' Java: The Complete Reference', ' Java For Dummies', ' Android Programming: The Big Nerd Ranch']], ['Trans2', ['A Beginner’s Guide', ' Java: The Complete Reference', ' Java For Dummies']], ['Trans3', ['A Beginner’s Guide', ' Java: The Complete Reference', ' Java For Dummies', ' Android Programming: The Big Nerd Ranch', ' Head First Java 2nd Edition']], ['Trans4', ['Android Programming: The Big Nerd Ranch', ' Head First Java 2nd Edition ', ' Beginning Programming with Java']], ['Trans5', ['Android Programming: The Big Nerd Ranch', ' Beginning Programming with Java', ' Java 8 Pocket Guide']], ['Trans6', ['A Beginner’s Guide', ' Android Programming: The Big Nerd Ranch', ' Head First Java 2nd Edition']], ['Trans7', ['A Beginner’s Guide', ' Head First Java 2nd Edition ', ' Beginning Programming with Java']], ['Trans8', ['Java: The Complete Reference', ' Java For Dummies', ' Android Programming: The Big Nerd Ranch']], ['Trans9', ['Java For Dummies', ' Android Programming: The Big Nerd Ranch', ' Head First Java 2nd Edition ', ' Beginning Programming with Java']], ['Trans10', ['Beginning Programming with Java', ' Java 8 Pocket Guide', ' C++ Programming in Easy Steps']], ['Trans11', ['A Beginner’s Guide', ' Java: The Complete Reference', ' Java For Dummies', ' Android Programming: The Big Nerd Ranch']], ['Trans12', ['A Beginner’s Guide', ' Java: The Complete Reference', ' Java For Dummies', ' HTML and CSS: Design and Build Websites']], ['Trans13', ['A Beginner’s Guide', ' Java: The Complete Reference', ' Java For Dummies', ' Java 8 Pocket Guide', ' HTML and CSS: Design and Build Websites']], ['Trans14', ['Java For Dummies', ' Android Programming: The Big Nerd Ranch', ' Head First Java 2nd Edition']], ['Trans15', ['Java For Dummies', ' Android Programming: The Big Nerd Ranch']], ['Trans16', ['A Beginner’s Guide', ' Java: The Complete Reference', ' Java For Dummies', ' Android Programming: The Big Nerd Ranch']], ['Trans17', ['A Beginner’s Guide', ' Java: The Complete Reference', ' Java For Dummies', ' Android Programming: The Big Nerd Ranch']], ['Trans18', ['Head First Java 2nd Edition ', ' Beginning Programming with Java', ' Java 8 Pocket Guide']], ['Trans19', ['Android Programming: The Big Nerd Ranch', ' Head First Java 2nd Edition']], ['Trans20', ['A Beginner’s Guide', ' Java: The Complete Reference', ' Java For Dummies']]]

# %%
init = []      # THIS FUNCTION SPECIFIES ALL THE INDIVISUAL ITEMSETS IN THE TRANSACTIONS
for i in db2:
    for q in i[1]:
        if(q not in init):
            init.append(q)

print(init)
# Out:
# ['A Beginner’s Guide', ' Java: The Complete Reference', ' Java For Dummies', ' Android Programming: The Big Nerd Ranch', ' Head First Java 2nd Edition', 'Android Programming: The Big Nerd Ranch', ' Head First Java 2nd Edition ', ' Beginning Programming with Java', ' Java 8 Pocket Guide', 'Java: The Complete Reference', 'Java For Dummies', 'Beginning Programming with Java', ' C++ Programming in Easy Steps', ' HTML and CSS: Design and Build Websites', 'Head First Java 2nd Edition ']

# %%
support = 0.70
s = int(support*len(init))

# %%
from collections import Counter #THIS FUCNTION CALCULATES C1 AND L1 WITH RESPECT TO MINIMUM SUPPORT
c = Counter()
for i in init:
    for d in db2:
        if(i in d[1]):
            c[i]+=1
print("C1:")
for i in c:
    print(str([i])+": "+str(c[i]))
print()
l = Counter()
for i in c:
    if(c[i] >= s):
        l[frozenset([i])]+=c[i]
print("L1:")
for i in l:
    print(str(list(i))+": "+str(l[i]))
print()
# Out:
# C1:
# ['A Beginner’s Guide']: 11
# [' Java: The Complete Reference']: 9
# [' Java For Dummies']: 10
# [' Android Programming: The Big Nerd Ranch']: 10
# [' Head First Java 2nd Edition']: 4
# ['Android Programming: The Big Nerd Ranch']: 3
# [' Head First Java 2nd Edition ']: 3
# [' Beginning Programming with Java']: 5
# [' Java 8 Pocket Guide']: 4
# ['Java: The Complete Reference']: 1
# ['Java For Dummies']: 3
# ['Beginning Programming with Java']: 1
# [' C++ Programming in Easy Steps']: 1
# [' HTML and CSS: Design and Build Websites']: 2
# ['Head First Java 2nd Edition ']: 1
#
# L1:
# ['A Beginner’s Guide']: 11
# [' Java For Dummies']: 10
# [' Android Programming: The Big Nerd Ranch']: 10

# %%
pl = l  #THIS FUCNTION IS FILLED WITH FOR LOOPS TO CONTINUOUS CALCULATE Cs AND Ls beyond C1 AND L1 UNTIL THERE IS ONLY ONE COMBINATION LEFT
pos = 1
for count in range (2,1000):
    nc = set()
    temp = list(l)
    for i in range(0,len(temp)):
        for j in range(i+1,len(temp)):
            t = temp[i].union(temp[j])
            if(len(t) == count):
                nc.add(temp[i].union(temp[j]))
    nc = list(nc)
    c = Counter()
    for i in nc:
        c[i] = 0
        for q in db2:
            temp = set(q[1])
            if(i.issubset(temp)):
                c[i]+=1
    print("C"+str(count)+":")
    for i in c:
        print(str(list(i))+": "+str(c[i]))
    print()
    l = Counter()
    for i in c:
        if(c[i] >= s):
            l[i]+=c[i]
    print("L"+str(count)+":")
    for i in l:
        print(str(list(i))+": "+str(l[i]))
    print()
    if(len(l) == 0):
        break
    pl = l
    pos = count
print("Result: ")
print("L"+str(pos)+":")
for i in pl:
    print(str(list(i))+": "+str(pl[i]))
print()
from itertools import combinations
for l in pl:
    c = [frozenset(q) for q in combinations(l,len(l)-1)]
    mmax = 0
    for a in c:
        b = l-a
        ab = l
        sab = 0
        sa = 0
        sb = 0
        for q in db2:
            temp = set(q[1])
            if(a.issubset(temp)):
                sa+=1
            if(b.issubset(temp)):
                sb+=1
            if(ab.issubset(temp)):
                sab+=1
        temp = sab/sa*100
        if(temp > mmax):
            mmax = temp
        temp = sab/sb*100
        if(temp > mmax):
            mmax = temp
        print(str(list(a))+" -> "+str(list(b))+" = "+str(sab/sa*100)+"%")
        print(str(list(b))+" -> "+str(list(a))+" = "+str(sab/sb*100)+"%")
    curr = 1
    print("choosing:", end=' ')
    for a in c:
        b = l-a
        ab = l
        sab = 0
        sa = 0
        sb = 0
        for q in db2:
            temp = set(q[1])
            if(a.issubset(temp)):
                sa+=1
            if(b.issubset(temp)):
                sb+=1
            if(ab.issubset(temp)):
                sab+=1
        temp = sab/sa*100
        if(temp == mmax):
            print(curr, end = ' ')
        curr += 1
        temp = sab/sb*100
        if(temp == mmax):
            print(curr, end = ' ')
        curr += 1
    print()
    print()
# Out:
# C2:
# [' Android Programming: The Big Nerd Ranch', 'A Beginner’s Guide']: 6
# [' Java For Dummies', ' Android Programming: The Big Nerd Ranch']: 6
# [' Java For Dummies', 'A Beginner’s Guide']: 9
#
# L2:
#
# Result:
# L1:
# ['A Beginner’s Guide']: 11
# [' Java For Dummies']: 10
# [' Android Programming: The Big Nerd Ranch']: 10
#
# [] -> ['A Beginner’s Guide'] = 55.00000000000001%
# ['A Beginner’s Guide'] -> [] = 100.0%
# choosing: 2
#
# [] -> [' Java For Dummies'] = 50.0%
# [' Java For Dummies'] -> [] = 100.0%
# choosing: 2
#
# [] -> [' Android Programming: The Big Nerd Ranch'] = 50.0%
# [' Android Programming: The Big Nerd Ranch'] -> [] = 100.0%
# choosing: 2

# %%
from itertools import combinations
for l in pl:
    c = [frozenset(q) for q in combinations(l,len(l)-1)]
    mmax = 0
    for a in c:
        b = l-a
        ab = l
        sab = 0
        
        sa = 0
        sb = 0
        for q in db2:
            temp = set(q[1])
            if(a.issubset(temp)):
                sa+=1
            if(b.issubset(temp)):
                sb+=1
            if(ab.issubset(temp)):
                sab+=1
        temp = sab/sa*100
        if(temp > mmax):
            mmax = temp
        temp = sab/sb*100
        if(temp > mmax):
            mmax = temp
        print(str(list(a))+" -> "+str(list(b))+" = "+str(sab/sa*100)+"%")
        print(str(list(b))+" -> "+str(list(a))+" = "+str(sab/sb*100)+"%")
    curr = 1
    print("choosing:", end=' ')
    for a in c:
        b = l-a
        ab = l
        sab = 0
        sa = 0
        sb = 0
        for q in db2:
            temp = set(q[1])
            if(a.issubset(temp)):
                sa+=1
            if(b.issubset(temp)):
                sb+=1
            if(ab.issubset(temp)):
                sab+=1
        temp = sab/sa*100
        if(temp == mmax):
            print(curr, end = ' ')
        curr += 1
        temp = sab/sb*100
        if(temp == mmax):
            print(curr, end = ' ')
        curr += 1
    print()
    print()
# Out:
# [] -> ['A Beginner’s Guide'] = 55.00000000000001%
# ['A Beginner’s Guide'] -> [] = 100.0%
# choosing: 2
#
# [] -> [' Java For Dummies'] = 50.0%
# [' Java For Dummies'] -> [] = 100.0%
# choosing: 2
#
# [] -> [' Android Programming: The Big Nerd Ranch'] = 50.0%
# [' Android Programming: The Big Nerd Ranch'] -> [] = 100.0%
# choosing: 2
